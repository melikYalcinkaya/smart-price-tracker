# %% [markdown]
# ## Keşifsel Veri Analizi
#
# Bu notebook, çekilen ürün ve fiyat verilerinin ilk incelemesi için kullanılır.
#
# **Amaç:** Ham fiyat verilerinin genel yapısını, dağılımını ve anomalilerini anlamak.
#
# **Girdiler:** `data/processed/merged_*.csv`
#
# **Çıktılar:** Keşifsel bulgular ve `visuals/` klasörüne kaydedilen grafikler.
