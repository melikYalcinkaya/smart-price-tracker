# %% [markdown]
# ## Modelleme
#
# Bu notebook, fiyat trendi analizi ve tahmin modelleri geliştirmek için kullanılır.
#
# **Amaç:** Fiyat değişim örüntülerini modellemek, gelecek fiyat tahminleri veya anomali tespiti yapmak.
#
# **Girdiler:** `data/processed/cleaned_*.csv`
#
# **Çıktılar:** Model sonuçları ve `visuals/` klasörüne kaydedilen değerlendirme grafikleri.
