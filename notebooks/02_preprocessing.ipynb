# %% [markdown]
# ## Veri Ön İşleme
#
# Bu notebook, ham fiyat verilerinin temizlenmesi ve analiz için hazırlanması için kullanılır.
#
# **Amaç:** Eksik değerleri gidermek, fiyat formatlarını normalize etmek, tarih sütunlarını standartlaştırmak.
#
# **Girdiler:** `data/processed/merged_*.csv`
#
# **Çıktılar:** Temizlenmiş DataFrame ve `data/processed/cleaned_*.csv`.
